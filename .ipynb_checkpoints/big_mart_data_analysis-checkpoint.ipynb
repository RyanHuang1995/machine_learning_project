# %%
# Dependencies
import os
import pandas as pd
# %matplotlib notebook
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.filterwarnings("ignore")

# %%
train_df = pd.read_csv("db/train_data.csv")
train_df.head()
# Out:
#    Unnamed: 0 Item_Fat_Content Item_Identifier  Item_MRP  Item_Outlet_Sales  \
# 0           0          Low Fat           FDA15  249.8092          3735.1380
# 1           1          Regular           DRC01   48.2692           443.4228
# 2           2          Low Fat           FDN15  141.6180          2097.2700
# 3           3          Regular           FDX07  182.0950           732.3800
# 4           4       Non-Edible           NCD19   53.8614           994.7052
#
#         Item_Type  Item_Weight Outlet_Identifier Outlet_Location_Type  \
# 0            Food         9.30            OUT049               Tier 1
# 1           Drink         5.92            OUT018               Tier 3
# 2            Food        17.50            OUT049               Tier 1
# 3            Food        19.20            OUT010               Tier 3
# 4  Non-consumable         8.93            OUT013               Tier 3
#
#   Outlet_Size        Outlet_Type source  Outlet_Years  \
# 0      Medium  Supermarket Type1  train            14
# 1      Medium  Supermarket Type2  train             4
# 2      Medium  Supermarket Type1  train            14
# 3       Small      Grocery Store  train            15
# 4        High  Supermarket Type1  train            26
#
#    Item_Visibility_Meanratio
# 0                   1.000000
# 1                   1.002515
# 2                   0.998508
# 3                   0.778300
# 4                   0.742195
